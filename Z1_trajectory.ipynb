# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = np.power(x, 2) # Effectively y = x**2
e = np.array([1.5, 2.6, 3.7, 4.6, 5.5])

plt.errorbar(x, y, e, linestyle='None', marker='*')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
x = np.array([1, 2, 3, 4, 5])  # Categorical variable
data1 = np.array([2, 4, 6, 8, 10])
data2 = np.array([1, 3, 5, 7, 20])
data3 = np.array([10, 5, 7, 9, 11])

# Calculate the mean and standard deviation for each data point
mean_values = np.mean([data1, data2, data3], axis=0)
std_values = np.std([data1, data2, data3], axis=0)

# Plot the average with error bars
plt.errorbar(x, mean_values, yerr=std_values, fmt='o-',linestyle='None', capsize=5, label='Mean with Std Dev')

# Add labels and legend
plt.xlabel('Categorical Variable')
plt.ylabel('Average Data Point')
plt.title('Average Data Point with Standard Deviation Error Bars')
plt.legend()

# Show the plot
plt.show()
# Out:
# /var/folders/wm/44bqfgw9477384mypv5vc8r80000gn/T/ipykernel_30218/334037715.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(x, mean_values, yerr=std_values, fmt='o-',linestyle='None', capsize=5, label='Mean with Std Dev')
